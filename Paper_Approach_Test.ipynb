# %%
import pandas as pd
import numpy as np
import networkx as nx
from tqdm import tqdm_notebook as tqdm

# %%
node_child_counts = {}
node_child_sets = {}
items = []
with open('../data/train.txt', 'rt') as f:
    line = f.readline()
    while line:
        numbers = line.split('\t')
        source = int(numbers[0])
        node_child_counts[source] = len(numbers)-1
        node_child_sets[source] = set(numbers[1:])
        for sink in numbers[1:]:
            items.append((source, int(sink)))
        line = f.readline()
len(items)
# Out:
# 24004361

# %%
DG = nx.DiGraph()
DG.add_edges_from(items)

# %%
G = DG.to_undirected()

# %% [markdown]
# #### Taking Source, Sink tuples from the testData, finding their common neighbors and store them in a dataframe `test_df`

# %%
test_edges = list(pd.read_csv('../data/testData_NetworkX_analysis_01Sep18.csv', usecols=['Source','Sink']).to_records(index=False))

# %%
common_neighbors = []
with tqdm(total=len(test_edges)) as pbar:
    for source, sink in test_edges:
        common_neighbors.append((source, sink, list(nx.common_neighbors(G, source, sink)),len(list(nx.common_neighbors(G, source, sink)))))
        pbar.update(1)
# Out:
# HBox(children=(IntProgress(value=0, max=2000), HTML(value='')))

# %%
test_df = pd.DataFrame.from_records(common_neighbors, columns=['Source','Sink','list_of_common_neighbors','number_of_common_neighbors'])
test_df.head()
# Out:
#     Source     Sink                           list_of_common_neighbors  \
# 0  2184483  1300190                                                 []
# 1  3151356  1452193                  [2120801, 36596, 404943, 2809458]
# 2  1579396   193159                                                 []
# 3  1406432  2481036  [2152768, 2789436, 4720169, 2307937, 2385853, ...
# 4  2389638   593017   [20388, 541698, 1565469, 282738, 82340, 2766242]
#
#    number_of_common_neighbors
# 0                           0
# 1                           4
# 2                           0
# 3                           7
# 4                           6

# %% [markdown]
# Storing it in a file: Common Neighbors

# %%
test_df.to_csv('../data/testCNB.csv', index = False)

# %% [markdown]
# #### Reading the training dataset to create comparision set: `string` and using that information to calculate `class2features` and storing it in Dataframe: `class2features_df`

# %%
train_df = pd.read_csv('../data/df.csv')
edgeStringSet = set(train_df['string'].unique())

# %%
class2features = []
with tqdm(total=len(common_neighbors)) as pbar:
for source, sink, neighbors, num_cnb in common_neighbors:
    t1 = t2 = t3 = t4 = 0
    for item in neighbors:
        source2neighbor = str(source) + ',' + str(item)
        sink2neighbor = str(sink) + ',' + str(item)
        neighbor2source = str(item) + ',' + str(source)
        neighbor2sink = str(item) + ',' + str(sink)
        if source2neighbor in edgeStringSet and neighbor2source in edgeStringSet:
            t1 = t1 + 1
        if source2neighbor in edgeStringSet and sink2neighbor in edgeStringSet:
            t2 = t2 + 1
        if neighbor2source in edgeStringSet and neighbor2sink in edgeStringSet:
            t3 = t3 + 1
        if neighbor2source in edgeStringSet and sink2neighbor in edgeStringSet:
            t4 = t4 + 1
    # print(t1, t2, t3, t4)
    if num_cnb == 0:
        class2features.append((source, sink, neighbors, num_cnb, t1, t2, t3, t4, 0, 0, 0, 0))
    else:
        class2features.append((source, sink, neighbors, num_cnb, t1, t2, t3, t4, t1/num_cnb, t2/num_cnb, t3/num_cnb, t4/num_cnb))
    pbar.update(1)

# %%
class2features_df = pd.DataFrame.from_records(class2features, columns=['source', 'sink', 'common_neighbors', 'num_cnb', 't1', 't2', 't3', 't4', 't1BYnum_cnb', 't2BYnum_cnb', 't3BYnum_cnb', 't4BYnum_cnb'])
class2features_df.head()
# Out:
#     source     sink                                   common_neighbors  \
# 0  2184483  1300190                                                 []
# 1  3151356  1452193                  [2120801, 36596, 404943, 2809458]
# 2  1579396   193159                                                 []
# 3  1406432  2481036  [2152768, 2789436, 4720169, 2307937, 2385853, ...
# 4  2389638   593017   [20388, 541698, 1565469, 282738, 82340, 2766242]
#
#    num_cnb  t1  t2  t3  t4  t1BYnum_cnb  t2BYnum_cnb  t3BYnum_cnb  t4BYnum_cnb
# 0        0   0   0   0   0     0.000000     0.000000     0.000000     0.000000
# 1        4   1   0   3   0     0.250000     0.000000     0.750000     0.000000
# 2        0   0   0   0   0     0.000000     0.000000     0.000000     0.000000
# 3        7   1   5   1   0     0.142857     0.714286     0.142857     0.000000
# 4        6   1   6   0   1     0.166667     1.000000     0.000000     0.166667

# %% [markdown]
# To get ID column for test dataset

# %%
testID = pd.read_csv('../data/test-public.txt', sep='\t')
testID.head()
# Out:
#    Id   Source     Sink
# 0   1  2184483  1300190
# 1   2  3151356  1452193
# 2   3  1579396   193159
# 3   4  1406432  2481036
# 4   5  2389638   593017

# %%
class2features_df = pd.merge(class2features_df, testID, how='inner', left_on=['source','sink'], right_on=['Source','Sink'], left_index=False, right_index=False)
class2features_df.head()
# Out:
#     source     sink                                   common_neighbors  \
# 0  2184483  1300190                                                 []
# 1  3151356  1452193                  [2120801, 36596, 404943, 2809458]
# 2  1579396   193159                                                 []
# 3  1406432  2481036  [2152768, 2789436, 4720169, 2307937, 2385853, ...
# 4  2389638   593017   [20388, 541698, 1565469, 282738, 82340, 2766242]
#
#    num_cnb  t1  t2  t3  t4  t1BYnum_cnb  t2BYnum_cnb  t3BYnum_cnb  \
# 0        0   0   0   0   0     0.000000     0.000000     0.000000
# 1        4   1   0   3   0     0.250000     0.000000     0.750000
# 2        0   0   0   0   0     0.000000     0.000000     0.000000
# 3        7   1   5   1   0     0.142857     0.714286     0.142857
# 4        6   1   6   0   1     0.166667     1.000000     0.000000
#
#    t4BYnum_cnb  Id   Source     Sink
# 0     0.000000   1  2184483  1300190
# 1     0.000000   2  3151356  1452193
# 2     0.000000   3  1579396   193159
# 3     0.000000   4  1406432  2481036
# 4     0.166667   5  2389638   593017

# %%
class2features_df.drop(['Source','Sink'], axis=1, inplace=True)
class2features_df.head()
# Out:
#     source     sink                                   common_neighbors  \
# 0  2184483  1300190                                                 []
# 1  3151356  1452193                  [2120801, 36596, 404943, 2809458]
# 2  1579396   193159                                                 []
# 3  1406432  2481036  [2152768, 2789436, 4720169, 2307937, 2385853, ...
# 4  2389638   593017   [20388, 541698, 1565469, 282738, 82340, 2766242]
#
#    num_cnb  t1  t2  t3  t4  t1BYnum_cnb  t2BYnum_cnb  t3BYnum_cnb  \
# 0        0   0   0   0   0     0.000000     0.000000     0.000000
# 1        4   1   0   3   0     0.250000     0.000000     0.750000
# 2        0   0   0   0   0     0.000000     0.000000     0.000000
# 3        7   1   5   1   0     0.142857     0.714286     0.142857
# 4        6   1   6   0   1     0.166667     1.000000     0.000000
#
#    t4BYnum_cnb  Id
# 0     0.000000   1
# 1     0.000000   2
# 2     0.000000   3
# 3     0.000000   4
# 4     0.166667   5

# %% [markdown]
# Saving features to file

# %%
class2features_df.to_csv('../data/2k_TEST_class2features.csv', index=False)

# %% [markdown]
# Reading First 8 feature dataset and removing unnecessary features for joining with `class2feature` set

# %%
class1features_df = pd.read_csv('../data/2k_TEST_class1features.csv')

# %%
class1features_df.drop(['AAprediction','Id','common_neighbors'], inplace=True, axis=1)
class1features_df.head()
# Out:
#     Source     Sink  source_in_degree  source_out_degree  sink_in_degree  \
# 0  2184483  1300190               102                 83               3
# 1  3151356  1452193                39                340             289
# 2  1579396   193159                13                208               2
# 3  1406432  2481036                16                 84              24
# 4  2389638   593017                30                267             165
#
#    sink_out_degree  source_outBYin_ratio  source_inBYout_ratio  \
# 0                0              0.813725              1.228916
# 1                0              8.717949              0.114706
# 2                0             16.000000              0.062500
# 3               14              5.250000              0.190476
# 4               58              8.900000              0.112360
#
#    sink_outBYin_ratio  sink_inBYout_ratio
# 0            0.000000            0.000000
# 1            0.000000            0.000000
# 2            0.000000            0.000000
# 3            0.583333            1.714286
# 4            0.351515            2.844828

# %% [markdown]
# ### Merging class 1 and class 2 features

# %%
class1and2features = pd.merge(class2features_df, class1features_df, how='inner', left_on=['source','sink'], right_on=['Source','Sink'], left_index=False, right_index=False)

# %%
class1and2features.drop(['Source','Sink'], axis=1, inplace=True)

# %%
class1and2features.head()
# Out:
#     source     sink                                   common_neighbors  \
# 0  2184483  1300190                                                 []
# 1  3151356  1452193                  [2120801, 36596, 404943, 2809458]
# 2  1579396   193159                                                 []
# 3  1406432  2481036  [2152768, 2789436, 4720169, 2307937, 2385853, ...
# 4  2389638   593017   [20388, 541698, 1565469, 282738, 82340, 2766242]
#
#    num_cnb  t1  t2  t3  t4  t1BYnum_cnb  t2BYnum_cnb         ...          \
# 0        0   0   0   0   0     0.000000     0.000000         ...
# 1        4   1   0   3   0     0.250000     0.000000         ...
# 2        0   0   0   0   0     0.000000     0.000000         ...
# 3        7   1   5   1   0     0.142857     0.714286         ...
# 4        6   1   6   0   1     0.166667     1.000000         ...
#
#    t4BYnum_cnb  Id  source_in_degree  source_out_degree  sink_in_degree  \
# 0     0.000000   1               102                 83               3
# 1     0.000000   2                39                340             289
# 2     0.000000   3                13                208               2
# 3     0.000000   4                16                 84              24
# 4     0.166667   5                30                267             165
#
#    sink_out_degree  source_outBYin_ratio  source_inBYout_ratio  \
# 0                0              0.813725              1.228916
# 1                0              8.717949              0.114706
# 2                0             16.000000              0.062500
# 3               14              5.250000              0.190476
# 4               58              8.900000              0.112360
#
#    sink_outBYin_ratio  sink_inBYout_ratio
# 0            0.000000            0.000000
# 1            0.000000            0.000000
# 2            0.000000            0.000000
# 3            0.583333            1.714286
# 4            0.351515            2.844828
#
# [5 rows x 21 columns]

# %% [markdown]
# Gettiong Adamic Adar & Jaccard Coefecient for Test Edges

# %%
link_prediction_coef = pd.read_csv('../data/testData_NetworkX_analysis_01Sep18.csv')
link_prediction_coef.drop(['PA','Id','common_neighbors'], axis=1, inplace=True)
link_prediction_coef.rename({'JA':'JAprediction'}, axis=1, inplace=True)
link_prediction_coef.head()
# Out:
#     Source     Sink  AAprediction  JAprediction
# 0  2184483  1300190      0.000000      0.000000
# 1  3151356  1452193      0.407705      0.006260
# 2  1579396   193159      0.000000      0.000000
# 3  1406432  2481036      1.238898      0.062500
# 4  2389638   593017      0.802812      0.012072

# %%
test_total = pd.merge(class1and2features, link_prediction_coef, how='inner', left_on=['source','sink'], right_on=['Source','Sink'], left_index=False, right_index=False)
test_total.head()
# Out:
#     source     sink                                   common_neighbors  \
# 0  2184483  1300190                                                 []
# 1  3151356  1452193                  [2120801, 36596, 404943, 2809458]
# 2  1579396   193159                                                 []
# 3  1406432  2481036  [2152768, 2789436, 4720169, 2307937, 2385853, ...
# 4  2389638   593017   [20388, 541698, 1565469, 282738, 82340, 2766242]
#
#    num_cnb  t1  t2  t3  t4  t1BYnum_cnb  t2BYnum_cnb      ...       \
# 0        0   0   0   0   0     0.000000     0.000000      ...
# 1        4   1   0   3   0     0.250000     0.000000      ...
# 2        0   0   0   0   0     0.000000     0.000000      ...
# 3        7   1   5   1   0     0.142857     0.714286      ...
# 4        6   1   6   0   1     0.166667     1.000000      ...
#
#    sink_in_degree  sink_out_degree  source_outBYin_ratio  \
# 0               3                0              0.813725
# 1             289                0              8.717949
# 2               2                0             16.000000
# 3              24               14              5.250000
# 4             165               58              8.900000
#
#    source_inBYout_ratio  sink_outBYin_ratio  sink_inBYout_ratio   Source  \
# 0              1.228916            0.000000            0.000000  2184483
# 1              0.114706            0.000000            0.000000  3151356
# 2              0.062500            0.000000            0.000000  1579396
# 3              0.190476            0.583333            1.714286  1406432
# 4              0.112360            0.351515            2.844828  2389638
#
#       Sink  AAprediction  JAprediction
# 0  1300190      0.000000      0.000000
# 1  1452193      0.407705      0.006260
# 2   193159      0.000000      0.000000
# 3  2481036      1.238898      0.062500
# 4   593017      0.802812      0.012072
#
# [5 rows x 25 columns]

# %%
test_total.drop(['Source','Sink'], inplace=True, axis=1)
test_total.head()
# Out:
#     source     sink                                   common_neighbors  \
# 0  2184483  1300190                                                 []
# 1  3151356  1452193                  [2120801, 36596, 404943, 2809458]
# 2  1579396   193159                                                 []
# 3  1406432  2481036  [2152768, 2789436, 4720169, 2307937, 2385853, ...
# 4  2389638   593017   [20388, 541698, 1565469, 282738, 82340, 2766242]
#
#    num_cnb  t1  t2  t3  t4  t1BYnum_cnb  t2BYnum_cnb      ...       \
# 0        0   0   0   0   0     0.000000     0.000000      ...
# 1        4   1   0   3   0     0.250000     0.000000      ...
# 2        0   0   0   0   0     0.000000     0.000000      ...
# 3        7   1   5   1   0     0.142857     0.714286      ...
# 4        6   1   6   0   1     0.166667     1.000000      ...
#
#    source_in_degree  source_out_degree  sink_in_degree  sink_out_degree  \
# 0               102                 83               3                0
# 1                39                340             289                0
# 2                13                208               2                0
# 3                16                 84              24               14
# 4                30                267             165               58
#
#    source_outBYin_ratio  source_inBYout_ratio  sink_outBYin_ratio  \
# 0              0.813725              1.228916            0.000000
# 1              8.717949              0.114706            0.000000
# 2             16.000000              0.062500            0.000000
# 3              5.250000              0.190476            0.583333
# 4              8.900000              0.112360            0.351515
#
#    sink_inBYout_ratio  AAprediction  JAprediction
# 0            0.000000      0.000000      0.000000
# 1            0.000000      0.407705      0.006260
# 2            0.000000      0.000000      0.000000
# 3            1.714286      1.238898      0.062500
# 4            2.844828      0.802812      0.012072
#
# [5 rows x 23 columns]

# %%
test_total.shape
# Out:
# (2000, 23)

# %%
test_total.columns
# Out:
# Index(['source', 'sink', 'common_neighbors', 'num_cnb', 't1', 't2', 't3', 't4',
#        't1BYnum_cnb', 't2BYnum_cnb', 't3BYnum_cnb', 't4BYnum_cnb', 'Id',
#        'source_in_degree', 'source_out_degree', 'sink_in_degree',
#        'sink_out_degree', 'source_outBYin_ratio', 'source_inBYout_ratio',
#        'sink_outBYin_ratio', 'sink_inBYout_ratio', 'AAprediction',
#        'JAprediction'],
#       dtype='object')

# %%
test_total.to_csv('../data/2k_TEST_All_features.csv', index=False)
